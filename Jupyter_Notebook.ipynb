# %% [markdown]
# # My Data Science Tools Notebook

# %% [markdown]
# ## Introduction
# This notebook serves as the final project for the Data Science Tools course. It covers various aspects of data science, including languages, libraries, tools, and basic arithmetic operations.

# %% [markdown]
# ## Data Science Languages
# Some of the popular languages used in data science include:
# 1. Python
# 2. R
# 3. SQL
# 4. Julia
# 5. Scala

# %% [markdown]
# ## Data Science Libraries
# Key libraries used in data science are:
# - **Pandas**: Data manipulation and analysis
# - **NumPy**: Numerical computing
# - **Matplotlib**: Data visualization
# - **Scikit-learn**: Machine learning
# - **TensorFlow**: Deep learning

# %% [markdown]
# ## Data Science Tools
# | Tool         | Description                         |
# |--------------|-------------------------------------|
# | Jupyter      | Interactive computing environment   |
# | RStudio      | Integrated development environment for R |
# | Apache Spark | Cluster computing framework         |
# | TensorFlow   | Deep learning framework             |
# | RapidMiner   | Data science platform               |

# %% [markdown]
# ## Arithmetic Expression Examples
# In this section, we will perform basic arithmetic operations such as addition and multiplication.

# %%
# Multiplication and Addition
a = 5
b = 4
result = a * b + b
result
# Out:
# 24

# %%
# Convert minutes to hours
minutes = 150
hours = minutes / 60
hours
# Out:
# 2.5

# %% [markdown]
# ## Objectives
# - List popular languages for Data Science
# - Identify key libraries used in Data Science
# - Present a table of Data Science tools
# - Perform basic arithmetic operations
# - Convert units from minutes to hours

# %% [markdown]
# ## Author
# Arun Arumugam
